# %%
import scipy.io
bpf = scipy.io.loadmat('D:\\crs\\proj\\MVCO\\2011_seasaw\\data_proc\\bpfodder.mat')

# %%
data = [bpf['abss2_ws2h'],bpf['UMEattn650_ws2h'],bpf['LISSTattn_ws2h'],bpf['UMEchl_ws2h']]
fig, ax1 = plt.subplots(figsize=(6,5))
plt.subplots_adjust(left=0.075, right=0.95, top=0.9, bottom=0.25)
bp = plt.boxplot(data,notch=0,whis=1.5)
plt.setp(bp['boxes'], color='black')
plt.setp(bp['whiskers'], color='black')
plt.setp(bp['fliers'], color='red', marker='+')
ax1.yaxis.grid(True, linestyle='-', which='major', color='darkgrey',
              alpha=0.5)
plt.ylim(ymin=-.004, ymax=.008)
plt.yticks(fontsize=14)
plt.ylabel('Apparent Settling Velocity $w_s$ (m/s)',fontsize=14)
plt.xticks([1, 2, 3, 4], ['2.5-MHz ABSS', 'c$_{p650}$', 'LISST c$_{p}$','Chl'],fontsize=15)
savefig('D:\\crs\\proj\\MVCO\\2011_seasaw\\data_proc\\bp.pdf',bbox_inches='tight',pad_inches=1)

# %%
import scipy.io
bpf = scipy.io.loadmat('C:\\crs\\proj\\MVCO\\2011_seasaw\\data_proc\\wsbox.mat')
data = [bpf['abss2_ws2h'],bpf['UMEbs650_ws2h'],bpf['UMEattn650_ws2h'],\
        bpf['tranattn_ws2h'],bpf['LISSTattn_ws2h'],\
        bpf['LISSTmacrov_ws2h'],bpf['LISSTfinesv_ws2h'],\
        bpf['UMEchl_ws2h']]
fig, ax1 = plt.subplots(figsize=(8,5))
plt.subplots_adjust(left=0.075, right=0.95, top=0.9, bottom=0.25)
bp = plt.boxplot(data,notch=0,whis=1.5)
plt.setp(bp['boxes'], color='black')
plt.setp(bp['whiskers'], color='black')
plt.setp(bp['fliers'], color='red', marker='+')
ax1.yaxis.grid(True, linestyle='-', which='major', color='darkgrey',
              alpha=0.5)
plt.ylim(ymin=-.004, ymax=.008)
plt.yticks(fontsize=14)
plt.ylabel('Apparent Settling Velocity $w_s$ (m/s)',fontsize=14)
plt.xticks([1, 2, 3, 4,5,6,7,8], ['ABSS','bs', 'ac9 c$_{p}$','SeaTech c$_{p}$',\
                          'LISST c$_{p}$','macro','micro','Chl'],fontsize=12)
savefig('C:\\crs\\proj\\MVCO\\2011_seasaw\\data_proc\\bp2.pdf',bbox_inches='tight',pad_inches=1)

# %%
import scipy.io
bpf = scipy.io.loadmat('C:\\crs\\proj\\MVCO\\2011_seasaw\\data_proc\\wsbox.mat')
data = [bpf['abss2_ws2h'],bpf['UMEattn650_ws2h'],\
        bpf['LISSTattn_ws2h'],bpf['UMEbs650_ws2h'],\
        bpf['UMEchl_ws2h']]
fig, ax1 = plt.subplots(figsize=(8,5))
plt.subplots_adjust(left=0.075, right=0.95, top=0.9, bottom=0.25)
bp = plt.boxplot(data,notch=0,whis=1.5)
plt.setp(bp['boxes'], color='black')
plt.setp(bp['whiskers'], color='black')
plt.setp(bp['fliers'], color='red', marker='+')
ax1.yaxis.grid(True, linestyle='-', which='major', color='darkgrey',
              alpha=0.5)
plt.ylim(ymin=-.002, ymax=.008)
plt.yticks(fontsize=14)
plt.ylabel('Apparent Settling Velocity $w_s$ (m/s)',fontsize=14)
plt.xticks([1, 2, 3, 4,5], ['ABSS', 'ac9 c$_{p}$',\
                          'LISST c$_{p}$','bs$_{650}$','Chl'],fontsize=14)
savefig('C:\\crs\\proj\\MVCO\\2011_seasaw\\data_proc\\bp2.png',bbox_inches='tight',pad_inches=1,\
        dpi=200)
